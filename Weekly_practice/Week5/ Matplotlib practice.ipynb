# %% [markdown]
# ##### 1. Import matplotlib.pyplot and create a basic line plot showing fare values of the first 10 passengers.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
f = pd.read_csv("train2.csv")

# %%
f
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.xlabel("PassengerId")
plt.ylabel("Fare")
plt.plot( f['Fare'].head(11), color = 'black' );
plt.grid()

# %% [markdown]
# ##### 2. Create a bar chart showing the number of passengers in each passenger class (Pclass).

# %%
pclass_counts = f['Pclass'].value_counts().sort_index()

# %%
plt.title('Bar Graph')
plt.xlabel('Pclass')
plt.ylabel('no. of  passengers')
plt.bar( pclass_counts.index,pclass_counts.values, color = 'pink', width = 0.5,edgecolor = 'black');
plt.grid()

# %% [markdown]
# ##### 3. Plot a histogram of the 'Age' column to visualize the distribution of ages

# %%
age = f['Age']

# %%
plt.figure(figsize=(14,7))
plt.xlabel("Distribution of age")
plt.ylabel("Frequency")
plt.hist(age,bins = 30,color = 'purple');
plt.grid()

# %% [markdown]
# ##### 4  Create a scatter plot comparing 'Age' and 'Fare'. Add labels and a title to the plot.

# %%
a =f['Age']
fa =f['Fare']
plt.title("Scatter plot")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.scatter(a,fa,color = 'purple' ,marker='o')
plt.grid()

# %%
f.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ##### 5. Create a pie chart showing the percentage of survivors vs non-survivors.

# %%
s_c = f['Survived'].value_counts()
labels = ['Survived','Non-Survived']

# %%
plt.title('Survivors vs Non-Survivors')
plt.pie(s_c,labels = labels,autopct = "%.2f%%");

# %% [markdown]
# ##### 6. Customize any one plot with: - X and Y labels - Title - Grid - Color and st

# %%
import warnings

warnings.filterwarnings('ignore', category=FutureWarning)

# %%
import seaborn as sns
plt.title('Number of Male vs Female Passengers on Titanic')
plt.xlabel('Gender', fontsize=12, color='darkgreen')
plt.ylabel('Number of Passengers', fontsize=12, color='darkgreen')
sns.countplot(x='Sex', data=f, palette={'male': 'cornflowerblue', 'female': 'lightpink'}, edgecolor='black');
plt.grid()

# %% [markdown]
# ##### 7. Create two subplots side-by-side: - Left: Bar chart of survival count by gender - Right: Pie chart of 'Embarked' values

# %%
plt.figure(figsize=(16,14))
plt.subplot(2,2,1)
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
sns.countplot(x='Sex', hue='Survived', data=f, 
              palette='Set2', edgecolor='black')
plt.grid()

plt.subplot(2,2,2)
plt.title('Passenger Embarkation Distribution')
embarked_counts = f['Embarked'].value_counts()
plt.pie(embarked_counts, 
        labels=embarked_counts.index, 
        autopct='%1.1f%%')
plt.grid()

# %% [markdown]
# ##### 8. Use figure() and subplot() to create a 2x2 layout: - Plot 4 different visualizations (line, bar, scatter, histogram) of relevant Titanic data.

# %%
plt.figure(figsize=(12,10))

plt.subplot(2, 2, 1)
plt.plot(f['PassengerId'], f['Fare'], color='purple')
plt.title('Fare per Passenger')
plt.xlabel('Passenger ID')
plt.ylabel('Fare')
plt.grid()

plt.subplot(2, 2, 2)
sns.countplot(x='Pclass', data=f, palette='pastel', edgecolor='black')
plt.title('Passenger Count by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.grid()

plt.subplot(2, 2, 3)
plt.scatter(f['Age'], f['Fare'], alpha=0.6, c='teal', edgecolors='black')
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid()

plt.subplot(2, 2, 4)
plt.hist(f['Age'].dropna(), bins=20, color='orange', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid()

plt.savefig('titanic_plot.png')

# %% [markdown]
# ##### 9.. Explain the difference between when to use a line plot vs a scatter plot using Titanic data as an example.

# %%
 # Line Plot: Used when you want to show how something changes in order (like fare over passenger ID)
plt.figure(figsize=(6,4))
plt.plot(f['PassengerId'], f['Fare'], color='orange')
plt.title('Fare by Passenger ID')
plt.xlabel('Passenger ID')
plt.ylabel('Fare')
plt.grid()

# This line plot shows how the ticket fare changes from one passenger to the next.

# %%
# Scatter Plot: Used when you want to see the connection between two things (like age and fare)
plt.figure(figsize=(6,4))
plt.scatter(f['Age'], f['Fare'], color='green', edgecolors='black', alpha=0.6)
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid()

# This scatter plot shows if there's any pattern between age and fare.
# It helps to check if older or younger passengers paid more or less.

# %% [markdown]
# ##### 10. . Create a stacked bar plot showing the number of survivors and non-survivors in each passenger class.

# %%
import numpy as np
data = f.groupby(['Pclass', 'Survived']).size().unstack(fill_value=0)
         # [1, 2, 3]
not_survived = data[0].values     # Survived = 0
survived = data[1].values        # Survived = 1
x = np.arange(len(data))
labels = ['Class 1', 'Class 2', 'Class 3']
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.title('Survivors and Non-Survivors by Class')
# Create stacked bar chart
plt.bar(x, not_survived, color='red', label='Not Survived')
plt.bar(x, survived, bottom=not_survived, color='green', label='Survived')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ##### 12 . Try customizing marker styles, colors, and sizes in the scatter plot of 'Age' vs 'Fare'.

# %%
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.scatter(f['Age'], f['Fare'],
            c='orange',marker='o', s=50)
plt.grid()
